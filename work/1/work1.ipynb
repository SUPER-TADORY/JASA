# %%
import numpy as np
import pandas as pd
import shutil
import os
import sys
import openpyxl

# %%
openpyxl.Workbook()
wb=openpyxl.load_workbook("/Users/tadokororyuu/JASA/work/September_2021/1/[Unlisted] Integrated GIMAP.xlsx")
sheet = wb["Vietnam"]
sheet
# Out:
# <Worksheet "Vietnam">

# %%
df1=pd.read_excel("/Users/tadokororyuu/JASA/work/September_2021/1/[Unlisted] Integrated GIMAP.xlsx",sheet_name="Vietnam")
df1.head(30)
# Out:
#     Collect Info. Trouble\nReport  Info.\nCollection  \
# 0            4504    Not Existing                NaN
# 1            5122    Not Existing                NaN
# 2            5876    Not Existing                NaN
# 3            5157    Not Existing                NaN
# 4            5221    Not Existing                NaN
# 5            4901    Not Existing                NaN
# 6             349          Listed                NaN
# 7            4062             NaN    hdoan@j-asa.net
# 8            6039             NaN  nnguyen@j-asa.net
# 9            5783    Not Existing                NaN
# 10           5060    Not Existing                NaN
# 11             75          Listed                NaN
# 12           4850    Not Existing                NaN
# 13           3236             NaN  nnguyen@j-asa.net
# 14           4028             NaN  nnguyen@j-asa.net
# 15          10094             NaN  nnguyen@j-asa.net
# 16           4057             NaN    hdoan@j-asa.net
# ...

# %%
df2=pd.read_csv("/Users/tadokororyuu/JASA/work/September_2021/1/Vietnam_Listed_All.csv")
df2.head(30)
# Out:
#    Stock Symbol                                            Company Board
# 0           AAA            An Phat Bioplastics Joint Stock Company  HOSE
# 1           AAM               Mekong Fisheries Joint Stock Company  HOSE
# 2           AAT             Tien Son Thanh Hoa Joint Stock Company  HOSE
# 3           ABS                Binh Thuan Agriculture Services JSC  HOSE
# 4           ABT  Bentre Aquaproduct Import And Export Joint Sto...  HOSE
# 5           ACB                   Asia Commercial Joint Stock Bank  HOSE
# 6           ACC  ACC Binh Duong Investment and Construction Joi...  HOSE
# 7           ACL                  Cuu Long Fish Joint Stock Company  HOSE
# 8           ADG                           Clever Group Corporation  HOSE
# 9           ADS                         Damsan Joint Stock Company  HOSE
# 10          AGG  An Gia Real Estate Investment and Development ...  HOSE
# 11          AGM                   An Giang Import - Export Company  HOSE
# ...

# %%
print(len(df1),len(df2))
# Out:
# 11643 1670

# %%
for i,row in df1.iterrows():
    newname=row["Company name\n(EN)"].lower()
    df1.loc[i,"Company name\n(EN)"]=newname

# %%
df1["Company name\n(EN)"]
# Out:
# 0        & medical biology pharmaceutical product enter...
# 1        & phu cuong pharmaceutical product and medical...
# 2        & quang minh pharmaceutical product and medica...
# 3        & thuc pham thang long pharmaceutical product ...
# 4        & viet hai pharmaceutical product joint stock ...
#                                ...
# 11638                   yudai sangyo representative office
# 11639            yung chang label (vietnam) company limted
# 11640                         yurtec representative office
# 11641    zuellig pharma company limited representative ...
# 11642              zuellig pharma viet nam company limited
# Name: Company name\n(EN), Length: 11643, dtype: object

# %%
df1[df1["Company name\n(EN)"].str.contains("refrigeration electrical engineering joint stock company".lower())]
# Out:
#        Collect Info. Trouble\nReport  Info.\nCollection  \
# 47              1012             NaN  nnguyen@j-asa.net
# 2839            8927             NaN                NaN
# 3335            8926             NaN                NaN
# 5185           10157             NaN                NaN
# 5749            6675             NaN                NaN
# 5753            6701             NaN                NaN
# 5819            1016             NaN                NaN
# 7687             935             NaN                NaN
# 7693            6688             NaN                NaN
# 7694            1163             NaN                NaN
# 7755            6700             NaN                NaN
# 8829            6939             NaN                NaN
# 9736             830             NaN                NaN
# 10474           6699             NaN                NaN
# 10916           6698             NaN                NaN
# 11067           6697             NaN                NaN
# ...

# %%
cnt=0
strange_dict={}
id_l=[]

for name in list(df2["Company"].values):
    try:
        tmp_df=df1[(df1["Company name\n(EN)"]==name.lower()) & (df1["Trouble\nReport"].isna())]
        n=len(tmp_df)
        indx=list(tmp_df.index)
        
        if len(indx)>0:
            id_l.append(indx[0])
        
        if n>0:
            cnt+=1
        elif n>1:
            strange_dict[name]=n
            
    except:
        print(name)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
len(id_l)
# Out:
# 43

# %%
cnt
# Out:
# 43

# %%
strange_dict
# Out:
# {}

# %%
id_l=sorted(id_l)
id_l
# Out:
# [43,
#  204,
#  244,
#  245,
#  753,
#  785,
#  848,
#  1110,
#  1145,
#  1207,
#  1306,
#  2202,
#  2630,
#  2630,
#  2977,
#  3241,
#  3318,
#  3437,
#  3446,
#  3659,
#  4520,
#  4541,
#  4774,
#  4929,
#  5265,
#  5507,
#  6636,
#  7439,
#  7445,
#  7467,
#  7841,
#  8088,
#  8245,
#  9484,
#  9600,
#  10837,
#  10881,
#  11215,
#  11318,
#  11445,
#  11449,
#  11506,
#  11507]

# %%
for id in id_l:
    sheet.cell(column=2,row=id+1).value = "Listed"

# %%
df1
# Out:
#        Collect Info. Trouble\nReport  Info.\nCollection  \
# 0               4504    Not Existing                NaN
# 1               5122    Not Existing                NaN
# 2               5876    Not Existing                NaN
# 3               5157    Not Existing                NaN
# 4               5221    Not Existing                NaN
# ...              ...             ...                ...
# 11638           7820             NaN                NaN
# 11639           4367             NaN                NaN
# 11640           8994             NaN                NaN
# 11641           5101          Double                NaN
# 11642           4939             NaN  nnguyen@j-asa.net
#
#        EN Contents\nConfirmation  JP Contents\nConfirmation  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# ...

# %% [markdown]
# **↓ jscが抜けているものを見つける(j.s.cのように表記されているものもあるため、気をつける)**

# %%
for i,row in df1.iterrows():
    name = "".join("".join(row["Company name\n(EN)"].lower().split()).split("."))
    df1.loc[i,"renamed"] = name
df1
# Out:
#        Collect Info. Trouble\nReport  Info.\nCollection  \
# 0               4504    Not Existing                NaN
# 1               5122    Not Existing                NaN
# 2               5876    Not Existing                NaN
# 3               5157    Not Existing                NaN
# 4               5221    Not Existing                NaN
# ...              ...             ...                ...
# 11638           7820             NaN                NaN
# 11639           4367             NaN                NaN
# 11640           8994             NaN                NaN
# 11641           5101          Double                NaN
# 11642           4939             NaN  nnguyen@j-asa.net
#
#        EN Contents\nConfirmation  JP Contents\nConfirmation  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2                            NaN                        NaN
# ...

# %%
cnt=0
strange_dict={}
id_l=[]
        
for name in list(df2["Company"].values):
    if  type(name)!=float and "jsc" in name.lower():
        a=name.lower().split()
        a=[o for o in a if not "jsc" in o]
        renamed = "".join(a)
        
        print(renamed)

        tmp_df = df1[(df1["Company name\n(EN)"]==renamed) & (df1["Trouble\nReport"].isna())]
        n=len(tmp_df)
        indx=list(tmp_df.index)

        if len(indx)>0:
            id_l.append(indx[0])
            print(tmp_df["Company name\n(EN)"], name)

        if n==1:
            cnt+=1
        elif n>1:
            strange_dict[name]=n
# Out:
# binhthuanagricultureservices
# ciiengineeringandconstruction
# dicholdingsconstruction
# vietnamairlines
# petrolimexgascorporation-
# viglaceracorporation-
# bentreaquaproductimportandexport
# acuongmineralgroup
# alphaname&c
# asia-pacificinvestment
# additivesandpetroleumproducts
# generalaviationimport–export
# bimsoncement
# danangbooksandschoolequipment
# baclieufisheries
# binhthuanbookandequipment
# constructionandinvestmentno.492
# camranhinternationalairportservices
# centralareaelectricalmechanical
# cokyvina
# cmcinvestment
# haiduongpumpmanufacturing
# vinam
# constreximno.8investmentandconstruction
# realestate11
# danangeducationdevelopmentandinvestment
# educationalbookindanangcity
# developmentinvestmentconstructionnumber2
# haiphongelectricalmechanical
# hataypharmaceutical
# developmentinvestmentconstructionhoian
# dongnaiplasticconstruction
# danangplastic
# thanhdatinvestmentdevelopment
# doanxaport
# bacna.,
# educationalbookinhanoicity
# ...

# %%
print(len(set(id_l)),id_l)
# Out:
# 1 [7036]

# %% [markdown]
# **↓ ~limited　になっているものは、確認するべきか**

# %%
cnt=0
strange_dict={}
id_l=[]
        
for name in list(df2["Company"].values):
    if  type(name)!=float and "jsc" in name.lower():
        a=name.lower().split()
        a=[o for o in a if not "jsc" in o]
        renamed = "".join(a)
        
        print(renamed)

        tmp_df = df1[(df1["Company name\n(EN)"]==renamed) & (df1["Trouble\nReport"].isna())]
        n=len(tmp_df)
        indx=list(tmp_df.index)

        if len(indx)>0:
            id_l.append(indx[0])
            print(tmp_df["Company name\n(EN)"], name)

        if n==1:
            cnt+=1
        elif n>1:
            strange_dict[name]=n

# %% [markdown]
# **↓略号になっているcolumnを見つける**

# %%
df1["ryaku"] = None

for i,row in df1.iterrows():
    ryaku1 = "".join(row["Company name\n(EN)"].split())
    df1.loc[i, "ryaku"] = ryaku1

# %%
data = sheet.values
df1 = pd.DataFrame(data)
df1.head(20)
# Out:
#                                                    0                1   \
# 0   =vlookup(sheetname(),Control!$A$60:$H$65,8,false)  Trouble\nReport
# 1                                              4504.0     Not Existing
# 2                                              5122.0     Not Existing
# 3                                              5876.0     Not Existing
# 4                                              5157.0     Not Existing
# 5                                              5221.0     Not Existing
# 6                                              4901.0     Not Existing
# 7                                               349.0           Listed
# 8                                              4062.0             None
# 9                                              6039.0             None
# 10                                             5783.0     Not Existing
# 11                                             5060.0     Not Existing
# ...

# %%
wb.save("Sample.xlsx")

# %% [markdown]
# **↓一応確認**

# %%
strange_dict={}
cnt=0

for name in list(df2["Company"].values):
    try:
        df1.loc[df1["Company name\n(EN)"].str.contains(name.lower()),"Trouble\nReport"]="Listed"
        n= len(df1[df1["Company name\n(EN)"].str.contains(name.lower())])
        if n>0:
            cnt+=1
        if n>1:
            strange_dict[name]=n
    
    except:
        strange_dict[name]=None
        print(name)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
cnt
# Out:
# 337

# %%
len(strange_dict)
# Out:
# 19

# %%
strange_dict
# Out:
# {nan: None,
#  'Cat Loi Joint Stock Company': 2,
#  'CMC Joint Stock Company': 2,
#  ' ': 11614,
#  'Nam Viet Joint Stock Company': 3,
#  'Pymepharco Joint Stock Company': 3,
#  'Phu Tai Joint Stock Company': 2,
#  'PetroVietNam Drilling & Well Service Corporation': 2,
#  'Century Synthetic Fiber Corporation': 2,
#  'Electrical Equipment Joint Stock Company': 8,
#  'Traphaco Joint Stock Company': 2,
#  'Thong Nhat Joint Stock Company': 3,
#  'Vinacontrol Group Corporation': 10,
#  'An Truong An Joint Stock Company': 2,
#  'Viettronics Bien Hoa Joint Stock Company': 2,
#  'Dong A Joint Stock Company': 2,
#  'HANEL Joint Stock Company': 2,
#  'Long Bien Joint Stock Company': 2,
#  'Machines and Industrial Equipment Corporation': 2}
